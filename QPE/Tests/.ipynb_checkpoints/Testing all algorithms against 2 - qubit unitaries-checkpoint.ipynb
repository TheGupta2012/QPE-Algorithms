# %% [markdown]
# ## Testing all the algorithms till now
# - All the algorithms, i.e., Basic, Iterative, SPEA are analysed for 1-qubit and 2-qubit matrices chosen manually.
# - One of the matrix that was chosen for two qubit gates was the **CP gate** and a matrix **ZX**.
#
# - **BASIS of TESTING**
#     - Each of the algorithm is given a unitary and run for increasing precision.
#     - The algorithm which converges faster is the better algorithm.
#     - Converges faster means the amount of iterations of the algorithm required to compute $\theta$ upto 6 bit precision

# %%
from qiskit import QuantumCircuit, execute, transpile, Aer 
from qiskit.extensions import UnitaryGate,Initialize
from qiskit.quantum_info import Statevector 
from qiskit.tools.visualization import plot_bloch_vector
from qiskit.tools.visualization import plot_histogram,plot_bloch_multivector  
import numpy as np 
from time import sleep 
import sys 
from scipy.stats import unitary_group 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from vanilla_qpe import QPE 
from multi_q_iterative_qpe import general_IQPE 
from normal_SPEA import SPEA

# %% [markdown]
# - **Controlled Phase gate**
# - Eigenvectors : $|00\rangle\ ,\ |01\rangle\ , |10\rangle\ and\ |11\rangle$
# - Eigenphases : $0\ or\ 1$ and $\frac{1}{7}$

# %%
# x gate 
u1 = QuantumCircuit(2)
u1.cp(2*np.pi*(1/7),0,1)
u1.draw('mpl')

# %% [markdown]
# - **ZX** unitary
# - Eigenvectors : $|0+\rangle\ , |1+\rangle , |1-\rangle and |0-\rangle$
# - Eigenphases : $0\ or\ 1$ and $\frac{1}{2}$

# %%
# x gate 
u2 = QuantumCircuit(2)
u2.z(0)
u2.x(1)
u2.draw('mpl')

# %% [markdown]
# ## Testing the Unitary Phase Estimation for CP(1/7)
# - Eigenvector chosen is : **|11>**
# - Phase reported should be ~ **0.1428**
# - **Basic QPE**

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
estimates = []
for precision in range(1,9): 
    qpe = QPE(precision=precision,unitary = u1)
    qpe_circ = qpe.get_QPE(show = False)
    qc = QuantumCircuit(precision+2,precision)
    qc.x(precision)
    qc.x(precision+1)
    qc.append(qpe_circ, qargs = list(range(precision+2)))
    qc.measure(list(range(precision)),list(range(precision)))
#     display(qc.draw('mpl')) 
    counts = execute(qc,backend=backend,shots = 2**10).result().get_counts()
    m = -1 
    for i,j in counts.items():
        if j > m:
            m = j 
            phase = i 
    factor = 0.5
    ans = 0.0 
    for i in range(precision):
        ans+= int(phase[i])*factor 
        factor/=2 
    estimates.append(ans)

# %%
plt.title("Phase by basic QPE for the unitary CP(1/7)",fontsize = 16)
plt.plot([i for i in range(1,9)],estimates,alpha = 0.5,color = 'g',linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([0,8],[0.1428,0.1428],color = 'black')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# - **IQPE**

# %%
estimates = []
for precision in range(1,9): 
    qpe = general_IQPE(precision=precision,unitary = u1,unknown=True)
    qc = QuantumCircuit(1+2,precision)
    qc.x(1)
    qc.x(2)    
    phase = qpe.get_circuit_phase(qc, qubits = [1,2], ancilla = 0,clbits = list(range(precision)),show = False)
#     display(qc.draw('mpl')) 
    estimates.append(phase[1])

# %%
plt.title("Phase by iterative QPE for the unitary CP(1/7)",fontsize = 16)
plt.plot([i for i in range(1,9)],estimates,color = 'b',alpha = 0.5,linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([0,8],[0.1428,0.1428],color = 'black')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# - **SPEA**

# %%
estimates = []
for resolution in range(10,40,5): 
    qpe = SPEA(resolution = resolution,unitary = u1, error =4,max_iters=12)
    result = qpe.get_eigen_pair(progress = True, backend = backend)
    print("Result : ",result)
    estimates.append(result['theta'])
# Out:
# Right : 1
# Left : 0.75
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.994140625
# THETA : 1.0
# Right : 1
# Left : 0.75
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# COST : 0.99609375
# THETA : 1.0
# Right : 1
# Left : 0.875
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 1.0
# Right : 1
# Left : 0.875
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# COST : 1.0
# THETA : 1.0
# Result :  {'cost': 1.0, 'theta': 1.0, 'state': array([-0.12890914-0.25865257j,  0.72528066-0.46031046j,
#        -0.16672658+0.3094523j ,  0.0354765 -0.23183283j])}
# Right : 0.25
# Left : 0
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0.982421875
# THETA : 0.03571428571428571
# Right : 0.1607142857142857
# Left : 0
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.982421875
# THETA : 0.03571428571428571
# Right : 0.1607142857142857
# Left : 0
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.982421875
# THETA : 0.03571428571428571
# Right : 0.1607142857142857
# Left : 0
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.982421875
# THETA : 0.03571428571428571
# Right : 0.1607142857142857
# Left : 0
# ITERATION NUMBER 5 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.982421875
# THETA : 0.03571428571428571
# Right : 0.1607142857142857
# Left : 0
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.984375
# THETA : 0.011479591836734693
# Right : 0.07397959183673469
# Left : 0
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# COST : 0.98828125
# THETA : 0.04755830903790087
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.98828125, 'theta': 0.04755830903790087, 'state': array([-0.73308016+0.19317288j, -0.23678859+0.26003861j,
#         0.24441639+0.14713902j,  0.46735388+0.04218876j])}
# Right : 1
# Left : 0.75
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.994140625
# THETA : 1.0
# Right : 1
# Left : 0.75
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.994140625
# THETA : 1.0
# Right : 1
# Left : 0.75
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.994140625
# THETA : 1.0
# Right : 1
# Left : 0.75
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.994140625
# THETA : 1.0
# Right : 1
# Left : 0.75
# ITERATION NUMBER 5 ...
# 100.000000 %completed
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Right : 1
# Left : 0.8618421052631579
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.9868421052631579
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.99609375, 'theta': 0.9868421052631579, 'state': array([-0.46792617+0.62074895j, -0.22356666-0.51848065j,
#        -0.02878122+0.0492222j , -0.11650313+0.24512739j])}
# Right : 0.3333333333333333
# Left : 0
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Right : 0.08585640138408304
# Left : 0
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.99609375
# THETA : 0.023356401384083045
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.99609375, 'theta': 0.023356401384083045, 'state': array([-0.05234848-0.03152284j,  0.5291814 +0.44742849j,
#         0.25879191+0.60114634j,  0.24172299+0.17105718j])}

# %%
plt.title("Phase by SQPE for the unitary CP(1/7)",fontsize = 16)
plt.plot([i for i in range(10,40,5)],estimates,color = 'g',linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([5,50],[0.1428,0.1428],color = 'black')
plt.plot([5,50],[0,0],color = 'black')
plt.plot([5,50],[1,1],color = 'black',label = 'Correct')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Testing PEA for ZX unitary
# - Eigenvector chosen **|0->**
# - Phase should be coming out as 1/2.
# - **Basic QPE**

# %%
estimates = []
for precision in range(1,9): 
    # 
    qpe = QPE(precision=precision,unitary = u2)
    qpe_circ = qpe.get_QPE(show = False)
    # Quantum Circuit 
    qc = QuantumCircuit(precision+2,precision)
    
    # make the eigenvector 
    qc.x(precision+1)
    qc.h(precision+1)
    qc.append(qpe_circ, qargs = list(range(precision+2)))
    qc.measure(list(range(precision)),list(range(precision)))
    
    counts = execute(qc,backend=backend,shots = 2**10).result().get_counts()
    m = -1 
    for i,j in counts.items():
        if j > m:
            m = j 
            phase = i 
    factor = 0.5
    ans = 0.0 
    for i in range(precision):
        ans+= int(phase[i])*factor 
        factor/=2 
    estimates.append(ans)

# %%
plt.title("Phase by basic QPE for the unitary ZX",fontsize = 16)
plt.plot([i for i in range(1,9)],estimates,alpha = 0.5,color = 'g',linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([0,8],[0.5,0.5],color = 'black')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# - **Iterative QPE**

# %%
estimates = []
for precision in range(1,9): 
    qpe = general_IQPE(precision=precision,unitary = u2,unknown=True)
    qc = QuantumCircuit(1+2,precision)
    # making the eigenvector
    qc.x(2)
    qc.h(2)    
    phase = qpe.get_circuit_phase(qc, qubits = [1,2], ancilla = 0,clbits = list(range(precision)),show = False)
#     display(qc.draw('mpl')) 
    estimates.append(phase[1])

# %%
plt.title("Phase by iterative QPE for the unitary ZX",fontsize = 16)
plt.plot([i for i in range(1,9)],estimates,color = 'b',alpha = 0.5,linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([0,8],[0.5,0.5],color = 'black')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# - **SPEA**

# %%
estimates = []
for resolution in range(10,40,5): 
    qpe = SPEA(resolution = resolution,unitary = u2, error =4,max_iters=12)
    result = qpe.get_eigen_pair(progress = True, backend = backend)
    print("Result : ",result)
    estimates.append(result['theta'])
# Out:
# Right : 1
# Left : 0.75
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0.92578125
# THETA : 0.9722222222222222
# Right : 1
# Left : 0.8472222222222222
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# COST : 0.95703125
# THETA : 1.0
# Right : 1
# Left : 0.9375
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# COST : 0.96484375
# THETA : 0.9791666666666666
# Right : 1
# Left : 0.9479166666666666
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0.716796875
# THETA : 0.9895833333333333
# Right : 1
# Left : 0.8645833333333333
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# COST : 0.75390625
# THETA : 0.9661458333333333
# Right : 1
# Left : 0.9036458333333333
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# COST : 0.759765625
# THETA : 0.9718967013888888
# Right : 1
# Left : 0.9406467013888888
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.759765625
# THETA : 0.9718967013888888
# Right : 1
# Left : 0.9406467013888888
# ITERATION NUMBER 5 ...
# 100.000000 %completed
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Right : 1
# Left : 0.9794288917824074
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.775390625
# THETA : 0.9950538917824074
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.775390625, 'theta': 0.9950538917824074, 'state': array([0.49326814+0.38735581j, 0.01787947+0.20379578j,
#        0.57746109-0.00766075j, 0.37201645+0.30475136j])}
# Right : 1
# Left : 0.7155172413793103
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0.818359375
# THETA : 0.9901902497027348
# Right : 1
# Left : 0.8651902497027348
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# COST : 0.853515625
# THETA : 0.9953513879207839
# Right : 1
# Left : 0.9328513879207839
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.853515625
# THETA : 0.9953513879207839
# Right : 1
# Left : 0.9328513879207839
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# COST : 0.87109375
# THETA : 0.9953690612359162
# Right : 1
# Left : 0.9641190612359162
# ITERATION NUMBER 5 ...
# 100.000000 %completed
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Right : 1
# Left : 0.9707649887446579
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.88671875
# THETA : 0.9863899887446579
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.88671875, 'theta': 0.9863899887446579, 'state': array([-0.11099336+0.47637622j,  0.14169494+0.26664187j,
#         0.27782962+0.43886749j, -0.57482274-0.26335465j])}
# Right : 0.3382352941176471
# Left : 0
# ITERATION NUMBER 1 ...
# 100.000000 %completed
# COST : 0.91796875
# THETA : 0.019896193771626297
# Right : 0.1448961937716263
# Left : 0
# ITERATION NUMBER 2 ...
# 100.000000 %completed
# COST : 0.953125
# THETA : 0.0
# Right : 0.0625
# Left : 0
# ITERATION NUMBER 3 ...
# 100.000000 %completed
# COST : 0.955078125
# THETA : 0.001838235294117647
# Right : 0.03308823529411765
# Left : 0
# ITERATION NUMBER 4 ...
# 100.000000 %completed
# COST : 0.958984375
# THETA : 0.012651384083044984
# Right : 0.028276384083044982
# Left : 0
# ITERATION NUMBER 5 ...
# 100.000000 %completed
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 6 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 7 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 8 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 9 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 10 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 11 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Right : 0.025277325463057193
# Left : 0.009652325463057193
# ITERATION NUMBER 12 ...
# 100.000000 %completed
# No change, updating a...
#
# COST : 0.98046875
# THETA : 0.017464825463057193
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result :  {'cost': 0.98046875, 'theta': 0.017464825463057193, 'state': array([-0.37457179+0.21843531j,  0.07278216-0.53523013j,
#        -0.23234232+0.50149003j, -0.00815206+0.46332688j])}

# %%
plt.title("Phase by SQPE for the unitary ZX",fontsize = 16)
plt.plot([i for i in range(10,40,5)],estimates,color = 'g',linewidth = 2,marker = 'o',label = 'Estimates')
plt.plot([5,50],[0.5,0.5],color = 'black')
plt.plot([5,50],[0,0],color = 'black')
plt.plot([5,50],[1,1],color = 'black',label = 'Correct')
plt.xlabel('Precision')
plt.ylabel('Estimates')
plt.grid()
plt.legend()
plt.show()
