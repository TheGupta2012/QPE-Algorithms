# %%
from scipy.stats import unitary_group 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
mat = []
for _ in range(3):
    mat.append(unitary_group.rvs(2**9))

# %%
def plot_eigs(i):
    matrix = mat[i]
    eig_val, eig_vector = np.linalg.eig(matrix)
    eig_val = np.angle(eig_val)
    eigs = []
    for k in eig_val:
        if k < 0:
            e = (k + 2*np.pi)/(2*np.pi)
        else:
            e = k/(2*np.pi)
        eigs.append(e)
    sns.scatterplot(range(2**9),eigs,label = str(i),color='green',alpha=0.6)
    plt.legend()
    plt.grid()

# %%
plot_eigs(2)
