# %% [markdown]
# ## Experiment 1
# - Seeing which algorithm converges faster given a particular unitary size and given resolution
# - Resolution ranges from [10,50] with a changed of 5 in between
# - Max iterations is 10 and error threshold is $10^{-3}$

# %%
resolutions = [i for i in range(10, 55, 5)]
resolutions
# Out:
# [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
from qiskit import IBMQ
from qiskit import QuantumCircuit, execute, transpile, Aer
from qiskit.extensions import UnitaryGate, Initialize
from qiskit.quantum_info import Statevector
from qiskit.tools.visualization import plot_bloch_vector
from qiskit.tools.visualization import plot_histogram, plot_bloch_multivector
import numpy as np
from time import sleep
import sys
import os
from scipy.stats import unitary_group
import matplotlib.pyplot as plt
# %matplotlib inline

# IBMQ.load_account()
# provider = IBMQ.get_provider(hub='ibm-q-education')
# santiago = provider.get_backend('ibmq_santiago')
# casablanca = provider.get_backend('ibmq_casablanca')
# bogota = provider.get_backend('ibmq_bogota')
sim = Aer.get_backend('qasm_simulator')
# athens = provider.get_backend('ibmq_athens')

# %%
from normal_SPEA import SPEA
from changed_SPEA import global_max_SPEA

# %% [markdown]
# ### Utils

# %%
def generate_plots(unitary_size, costs, errors, overlaps, algorithm):
    import random
    colors = ['red', 'brown', 'cyan', 'green',
              'grey', 'blue', 'purple', 'black', 'orange']
    c1, c2, c3 = random.sample(colors, 3)

    # plot
    os.makedirs("Experiment_1/"+str(unitary_size) +
                "_qubit(random)/", exist_ok=True)
    # plot 1
    fig = plt.figure(figsize=(13, 6))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.set_title(str(unitary_size)+" qubit "+algorithm +
                  " Cost v/s Max iters", fontsize=16)
    ax1.set_xlabel("Number of Resolutions ", fontsize=15)
    ax1.set_ylabel("Metrics Returned for unitary ", fontsize=15)
    ax1.plot(resolutions, costs, label='Costs of Unitary',
             marker='o', color=c1, alpha=0.7)
    ax1.plot(resolutions, overlaps, label='Average overlap from nearest eigenvector',
             marker='s', color=c2, alpha=0.6)
    ax1.legend(loc='best')
    ax1.grid()
    # plot 2
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.set_title(str(unitary_size)+" qubit "+algorithm +
                  " % error v/s Max iters", fontsize=16)
    ax2.set_xlabel("Number of resolutions ", fontsize=15)
    ax2.set_ylabel("% error for nearest eigenvalue", fontsize=15)
    ax2.plot(resolutions, errors, label='Average error from nearest eigenvalue',
             marker='o', color=c3, alpha=0.6)
    ax2.legend(loc='best')
    ax2.grid()
    # save axure
    fig.savefig("Experiment_1/"+str(unitary_size)+"_qubit(random)/" +
                algorithm+" Algorithm (alternate).JPG", dpi=200)

# %%
def get_results(eig_vals, eig_vect, bases, basis_indices, unitary, algorithm, experiments):
    '''Return the results of running the algorithm for this particular unitary matrix'''
    costs_g = []
    errors_g = []
    max_overlaps_g = []
    # find how the cost converges with increasing iterations
    for reso in resolutions:
        costs = []
        errors = []
        overlaps = []
        i = 0
        # run the experiments ...
        while len(costs) < experiments:
            if algorithm == 'original':
                spea = SPEA(unitary, resolution=reso, error=3, max_iters=10)
            else:
                spea = global_max_SPEA(
                    unitary, resolution=reso, error=3, max_iters=10)

            result = spea.get_eigen_pair(
                progress=False, backend=sim, algo='alternate', basis=bases[i], basis_ind=basis_indices[i],
                randomize=False,shots = 256)

#             if result['cost'] < 0.65:
#                 continue
                
            # increment the basis index 
            i+=1  # in exp 1 -> basis[0], in exp 2 -> basis[1] and so on....
            
            # find the costs
            costs.append(result['cost'])
            theta = result['theta']
            res_state = result['state']

            # find the abs difference in this theta with the closest eigenvalue
            # and append that to the errors ...
            min_error = 1e5
            for e in eig_vals:
                error = abs(e - theta)
                if error < min_error:
                    min_error = error
                    perc_error = ((error)/e)*100
            errors.append(perc_error)

            # find overlaps
            max_overlap = -1
            for k in eig_vect:
                dot = np.linalg.norm(np.dot(k, res_state.conjugate().T))**2
                max_overlap = max(max_overlap, dot)
            overlaps.append(max_overlap)
        
        print("Result with", reso, " resolutions :")
        print("AVG. COST :", np.average(costs),
              "AVG. ERROR :", np.average(errors))
        # append the average result of your algorithm ...
        costs_g.append(np.average(costs))
        errors_g.append(np.average(errors))
        max_overlaps_g.append(np.average(overlaps))

    return costs_g, errors_g, max_overlaps_g

# %% [markdown]
# ## 2 - qubit unitary

# %%
unit_2 = unitary_group.rvs(4)
unit_2
# Out:
# array([[-0.44073978-0.61244037j,  0.42154839-0.13995441j,
#          0.39120864-0.00344771j,  0.11766397+0.25782565j],
#        [ 0.37410688-0.19213783j, -0.09981332-0.10732826j,
#          0.36583611-0.76268176j, -0.24120458-0.16717017j],
#        [-0.35220543-0.22629297j, -0.07129549+0.45226318j,
#          0.02063494+0.02996362j, -0.05979849-0.78116472j],
#        [ 0.15719523+0.23200178j,  0.63977708+0.40284975j,
#         -0.13858936-0.33300715j,  0.46852953-0.01554056j]])

# %%
eig_vals2, eig_vect2 = np.linalg.eig(unit_2)
eig_vals2 = np.angle(eig_vals2)
e = []
for k in eig_vals2:
    if k < 0:
        v = (k + 2*np.pi)/(2*np.pi)
    else:
        v = (k)/(2*np.pi)
    e.append(v)
eig_vals2 = np.array(e)
print("Eigenstates :", eig_vect2)
print("Eigenvalues :", eig_vals2)
# Out:
# Eigenstates : [[-0.53574453+0.04137286j  0.13641182+0.11528262j  0.79833247+0.j
#    0.14651723-0.14340772j]
#  [ 0.65390077+0.j          0.1410471 +0.40593384j  0.23615001+0.0696627j
#    0.10290673-0.56260795j]
#  [-0.06532085-0.49015487j -0.61353681-0.02320524j -0.01968498-0.43663784j
#    0.35816699-0.24329361j]
#  [-0.1182188 -0.15869961j  0.63754157+0.j         -0.30225238-0.14017466j
#    0.66586339+0.j        ]]
# Eigenvalues : [0.5056535  0.17275683 0.69905785 0.89655855]

# %% [markdown]
# ### Generate Basis set

# %%
bases2 , basis_indices2 = [], []
for _ in range(4):
    sample = unitary_group.rvs(4)
    basis = []
    for k in sample:
        basis.append(np.array(k, dtype=complex))
    ind = np.random.choice(range(4))
    bases2.append(basis)
    basis_indices2.append(ind)
print("Basis set :",bases2)
print("Basis indices :",basis_indices2)
# Out:
# Basis set : [[array([ 0.11371028+0.12222719j,  0.51231072+0.17665853j,
#         0.21349067-0.24098387j, -0.11714207-0.74905688j]), array([-0.59727878+0.15841358j, -0.08623432+0.01748937j,
#         0.37514164-0.65129374j, -0.0567102 +0.20564562j]), array([-0.42307426-0.36107465j,  0.68281228+0.04129173j,
#        -0.34587686+0.05320838j,  0.24587242+0.19945042j]), array([-0.42857075-0.31185583j, -0.46948805+0.10114643j,
#        -0.4560416 -0.0315887j , -0.127023  -0.51314403j])], [array([-0.59728289+0.42471928j,  0.35868207+0.03171724j,
#        -0.47408505+0.26626786j, -0.02482668-0.19218818j]), array([-0.36095832-0.44144765j,  0.01888697-0.44355598j,
#         0.2124223 +0.52489029j,  0.28586463+0.27455929j]), array([ 0.26891568-0.139951j  , -0.37210293+0.24886298j,
#        -0.26834215+0.47512434j,  0.36584752-0.52546136j]), array([-0.11424152+0.18096049j, -0.31841701+0.60947502j,
#         0.01886644+0.29258357j, -0.05125655+0.62670939j])], [array([ 0.00228472-0.20328658j, -0.39886602-0.15288894j,
#        -0.03832672-0.23653633j, -0.39604347+0.74962085j]), array([ 0.51047424+0.5911875j , -0.54656132+0.20273653j,
#         0.0793219 -0.16472974j,  0.02156135-0.12723707j]), array([-0.45895895+0.15770714j, -0.09994237+0.36739147j,
#        -0.59882759-0.22522948j, -0.38963649-0.24162112j]), array([-0.25633836-0.21762014j, -0.42722735+0.38757103j,
#         0.40980571+0.57609917j, -0.20458197-0.11186082j])], [array([-0.73857249+0.08610039j, -0.27042265+0.51509378j,
#         0.23865665+0.14374338j,  0.01220696+0.17572487j]), array([-0.5124739 +0.06165772j,  0.03428172-0.47597225j,
#        -0.01099321-0.64103297j, -0.25014705-0.17951696j]), array([ 0.36477477-0.08868921j, -0.48104993+0.21824521j,
#         0.3426849 -0.62039209j,  0.16116554+0.22746421j]), array([-0.06419809+0.18872846j, -0.36854007-0.13770762j,
#         0.00250134+0.09492722j,  0.61219859-0.64936158j])]]
# Basis indices : [0, 2, 2, 0]

# %% [markdown]
# ### Algorithm 1

# %%
costs_2qubit_b, errors_eig_2qubit_b, max_overlaps_2qubit_b = get_results(
    eig_vals2, eig_vect2, bases2, basis_indices2, unit_2, 'original', 4)
generate_plots(2, costs_2qubit_b, errors_eig_2qubit_b,
               max_overlaps_2qubit_b, "Original")
# Out:
# E:\ANACONDA\lib\site-packages\qiskit\circuit\quantumcircuit.py:869: DeprecationWarning: The QuantumCircuit.combine() method is being deprecated. Use the compose() method which is more flexible w.r.t circuit register compatibility.
#   return self.combine(rhs)
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 10  resolutions :
# AVG. COST : 0.8994140625 AVG. ERROR : 7.789627978573256
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 15  resolutions :
# AVG. COST : 0.873046875 AVG. ERROR : 10.01948397113704
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 20  resolutions :
# AVG. COST : 0.8994140625 AVG. ERROR : 9.129064935710547
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 25  resolutions :
# AVG. COST : 0.861328125 AVG. ERROR : 15.16153668065699
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 30  resolutions :
# AVG. COST : 0.939453125 AVG. ERROR : 7.096662485723563
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 35  resolutions :
# AVG. COST : 0.943359375 AVG. ERROR : 7.494405495757897
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 40  resolutions :
# AVG. COST : 0.908203125 AVG. ERROR : 4.167739450171925
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 45  resolutions :
# AVG. COST : 0.89453125 AVG. ERROR : 12.821040131697993
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 50  resolutions :
# AVG. COST : 0.916015625 AVG. ERROR : 5.867099017018754

# %% [markdown]
# ### Algorithm 2

# %%
costs_2qubit_c, errors_eig_2qubit_c, max_overlaps_2qubit_c = get_results(
    eig_vals2, eig_vect2, bases2, basis_indices2, unit_2, 'modified', 4)
generate_plots(2, costs_2qubit_c, errors_eig_2qubit_c,
               max_overlaps_2qubit_c, "Modified")
# Out:
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 10  resolutions :
# AVG. COST : 0.880859375 AVG. ERROR : 10.214363133565572
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 15  resolutions :
# AVG. COST : 0.9306640625 AVG. ERROR : 8.445850738136134
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 20  resolutions :
# AVG. COST : 0.9150390625 AVG. ERROR : 7.511000229537686
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 25  resolutions :
# AVG. COST : 0.861328125 AVG. ERROR : 14.476348743923829
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 30  resolutions :
# AVG. COST : 0.8515625 AVG. ERROR : 16.737770633218897
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 35  resolutions :
# AVG. COST : 0.90234375 AVG. ERROR : 9.006436114857362
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 40  resolutions :
# AVG. COST : 0.88671875 AVG. ERROR : 15.672404249764433
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 45  resolutions :
# AVG. COST : 0.8642578125 AVG. ERROR : 12.652364985589282
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 50  resolutions :
# AVG. COST : 0.89453125 AVG. ERROR : 9.62629662816262

# %% [markdown]
# ## 3 - qubit unitary

# %%
unit_3 = unitary_group.rvs(8)
unit_3
# Out:
# array([[-0.4532812 +0.16712029j,  0.29636002+0.28014512j,
#         -0.08738532-0.08842713j,  0.05681374-0.20759914j,
#          0.04724163-0.23878782j,  0.33203611-0.26028839j,
#         -0.06578606-0.3327491j ,  0.06647286+0.42637756j],
#        [ 0.47450474+0.31702822j, -0.37518825+0.12800177j,
#          0.29977501-0.21384301j,  0.24752437-0.09759417j,
#          0.00298508-0.14488532j, -0.16426445+0.13772038j,
#         -0.00094323-0.32425795j,  0.12268134+0.35164706j],
#        [-0.04700457-0.26541418j, -0.03631463-0.18530027j,
#         -0.28389855-0.51681908j, -0.08003083+0.08848506j,
#         -0.2013405 -0.14606578j, -0.46707978-0.28742756j,
#          0.04222036-0.12254472j, -0.34209676+0.18241369j],
#        [ 0.21235766+0.18816053j,  0.30292322-0.09879495j,
#         -0.14322357-0.04262746j, -0.61650576-0.0822228j ,
#          0.16635549-0.05600781j,  0.03957076+0.42402533j,
#          0.27457795-0.29851358j, -0.17741036+0.02558707j],
#        [ 0.01029227+0.17718799j,  0.38042865+0.18614237j,
#         -0.1014629 -0.2647606j ,  0.31943513+0.4684315j ,
#          0.50460939+0.00482463j, -0.21712493+0.13144452j,
#         -0.18228962-0.01762379j,  0.02279666-0.18474082j],
#        [ 0.07241664+0.01106694j,  0.41505008+0.29262388j,
#          0.20909053+0.12071885j,  0.14935939+0.30874787j,
#         -0.66105887-0.1193191j , -0.07505551+0.14762637j,
#          0.27374781+0.02565595j, -0.07852209+0.019701j  ],
#        [-0.16974397-0.44154542j,  0.12908301-0.16930086j,
#          0.29406258+0.26976836j,  0.03235964-0.07518811j,
#          0.19060227-0.25687362j, -0.3872501 +0.03430076j,
#          0.14365413-0.38174615j,  0.37097926-0.08664034j],
#        [-0.16410346+0.01474993j, -0.05318506-0.23224298j,
#          0.02798205-0.4245051j , -0.0557379 +0.18138336j,
#          0.01890021-0.13602727j,  0.17152111+0.14664367j,
#          0.41806671+0.38499396j,  0.52196449+0.18401436j]])

# %%
eig_vals3, eig_vect3 = np.linalg.eig(unit_3)
eig_vals3 = np.angle(eig_vals3)
e = []
for k in eig_vals3:
    if k < 0:
        v = (k + 2*np.pi)/(2*np.pi)
    else:
        v = (k)/(2*np.pi)
    e.append(v)
eig_vals3 = np.array(e)
print("Eigenstates :", eig_vect3)
print("Eigenvalues :", eig_vals3)
# Out:
# Eigenstates : [[ 0.23660943-0.31837625j  0.01384821+0.25439166j -0.12796355-0.14087375j
#   -0.48766896+0.11256688j  0.15240822+0.02336771j  0.15300442+0.3412557j
#    0.55225533+0.j         -0.14769779+0.02434227j]
#  [ 0.33647221-0.14164868j  0.00960303+0.29286248j  0.00216823-0.11255224j
#   -0.14092729+0.47044303j  0.3168903 -0.16601533j -0.37584161-0.2717759j
#   -0.40425571+0.1028312j   0.0355849 -0.09299875j]
#  [-0.12719303+0.28449555j -0.05448911+0.0484686j  -0.16404613+0.12698629j
#    0.02174384+0.04979006j  0.35542377-0.34514165j  0.21425821-0.14159086j
#    0.29860279+0.35191753j  0.57198296+0.j        ]
#  [ 0.2047059 -0.07282765j -0.05063553+0.08823435j  0.12803901-0.24242805j
#    0.29872187-0.02155916j  0.13552164-0.06203767j  0.6975352 +0.j
#   -0.20862297+0.18617684j -0.23806215-0.36598959j]
#  [-0.03449271-0.31637818j -0.28914996+0.26140054j  0.70444763+0.j
#    0.24635985-0.09515722j  0.08404664-0.08242111j -0.04694297-0.07930365j
#    0.18967535-0.09137509j  0.15414395+0.30057666j]
#  [ 0.50197589+0.j          0.11437013-0.03071627j -0.2795793 -0.21796202j
#    0.50428088+0.j          0.06323775+0.39827948j -0.06013415-0.08266117j
#    0.22003954-0.17792643j  0.27185361+0.16422793j]
#  [-0.11958221+0.32436031j  0.32393251-0.17089991j  0.24091051-0.08085082j
#    0.12524874-0.02937897j  0.62865021+0.j         -0.20151004+0.03153334j
#    0.22081307-0.13902491j -0.39482916-0.06669481j]
#  [ 0.30330005-0.01689246j  0.73038615+0.j          0.30182159+0.23519294j
#   -0.2049099 -0.18191598j -0.09151233-0.0228757j   0.17838224-0.01194394j
#   -0.14902705+0.12298546j  0.1788157 +0.20638819j]]
# Eigenvalues : [0.22558051 0.04289527 0.98202713 0.36787023 0.80304517 0.48949288
#  0.58442727 0.65994908]

# %% [markdown]
# ### Generate Basis

# %%
bases3 , basis_indices3 = [], []
for _ in range(4):
    sample = unitary_group.rvs(8)
    basis = []
    for k in sample:
        basis.append(np.array(k, dtype=complex))
    ind = np.random.choice(range(8))
    bases3.append(basis)
    basis_indices3.append(ind)
print("Basis indices :",basis_indices3)
# Out:
# Basis indices : [7, 7, 4, 4]

# %% [markdown]
# - Algorithm 1

# %%
costs_3qubit_b, errors_eig_3qubit_b, max_overlaps_3qubit_b = get_results(
    eig_vals3, eig_vect3, bases3, basis_indices3, unit_3, 'original', 4)
# Out:
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 10  resolutions :
# AVG. COST : 0.8779296875 AVG. ERROR : 9.254578764706968
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 15  resolutions :
# AVG. COST : 0.82421875 AVG. ERROR : 3.094565872995063
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 20  resolutions :
# AVG. COST : 0.9091796875 AVG. ERROR : 3.6473127415341953
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 25  resolutions :
# AVG. COST : 0.9228515625 AVG. ERROR : 5.097858946000434
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 30  resolutions :
# AVG. COST : 0.8447265625 AVG. ERROR : 11.974361723034018
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 35  resolutions :
# AVG. COST : 0.8408203125 AVG. ERROR : 5.44644727277319
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 40  resolutions :
# AVG. COST : 0.8447265625 AVG. ERROR : 10.967287211102004
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 45  resolutions :
# AVG. COST : 0.876953125 AVG. ERROR : 11.945174449023817
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 50  resolutions :
# AVG. COST : 0.8759765625 AVG. ERROR : 4.691195804170209

# %%
generate_plots(3, costs_3qubit_b, errors_eig_3qubit_b,
               max_overlaps_3qubit_b, "Original")

# %% [markdown]
# - Algorithm 2

# %%
costs_3qubit_c, errors_eig_3qubit_c, max_overlaps_3qubit_c = get_results(
    eig_vals3, eig_vect3, bases3, basis_indices3, unit_3, 'modified', 4)
generate_plots(3, costs_3qubit_c, errors_eig_3qubit_c,
               max_overlaps_3qubit_c, "Modified")
# Out:
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 10  resolutions :
# AVG. COST : 0.8076171875 AVG. ERROR : 8.56139720313004
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 15  resolutions :
# AVG. COST : 0.8525390625 AVG. ERROR : 7.998087248623012
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 20  resolutions :
# AVG. COST : 0.861328125 AVG. ERROR : 6.415674474161158
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 25  resolutions :
# AVG. COST : 0.828125 AVG. ERROR : 5.170026355741691
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 30  resolutions :
# AVG. COST : 0.82421875 AVG. ERROR : 10.508615403037027
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 35  resolutions :
# AVG. COST : 0.849609375 AVG. ERROR : 5.614703412115507
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 40  resolutions :
# AVG. COST : 0.849609375 AVG. ERROR : 7.544131277364175
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 45  resolutions :
# AVG. COST : 0.84765625 AVG. ERROR : 4.96352951820216
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Maximum iterations reached for the estimation.
# Terminating algorithm...
# Result with 50  resolutions :
# AVG. COST : 0.7763671875 AVG. ERROR : 5.1666343839732605

# %% [markdown]
# ## 4 - qubit unitary

# %%
unit_4 = unitary_group.rvs(16)
unit_4

# %%
eig_vals4, eig_vect4 = np.linalg.eig(unit_4)
eig_vals4 = np.angle(eig_vals4)
e = []
for k in eig_vals4:
    if k < 0:
        v = (k + 2*np.pi)/(2*np.pi)
    else:
        v = (k)/(2*np.pi)
    e.append(v)
eig_vals4 = np.array(e)
print("Eigenstates :", eig_vect4)
print("Eigenvalues :", eig_vals4)

# %% [markdown]
# ### Generate basis set

# %%
bases4 , basis_indices4 = [], []
for _ in range(4):
    sample = unitary_group.rvs(16)
    basis = []
    for k in sample:
        basis.append(np.array(k, dtype=complex))
    ind = np.random.choice(range(16))
    bases4.append(basis)
    basis_indices4.append(ind)
print("Basis indices :",basis_indices4)

# %% [markdown]
# - Algorithm 1

# %%
costs_4qubit_b, errors_eig_4qubit_b,  max_overlaps_4qubit_b = get_results(
    eig_vals4, eig_vect4, bases4, basis_indices4, unit_4, 'original', 4)
generate_plots(4, costs_4qubit_b, 
               errors_eig_4qubit_b, max_overlaps_4qubit_b,  "Original")

# %% [markdown]
# - Algorithm 2

# %%
costs_4qubit_c, errors_eig_4qubit_c, max_overlaps_4qubit_c = get_results(
    eig_vals4, eig_vect4, bases4, basis_indices4, unit_4, 'modified', 4)
generate_plots(4, costs_4qubit_c, 
               errors_eig_4qubit_c,max_overlaps_4qubit_c, "Modified")
